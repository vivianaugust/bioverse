# %%
# Installation step
# %pip install numpy pandas bioverse==1.1.8
# Out:
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (2.3.3)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (2.3.2)
# Requirement already satisfied: bioverse==1.1.8 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (1.1.8)
# Requirement already satisfied: sphinx in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from bioverse==1.1.8) (8.1.3)
# Requirement already satisfied: nbsphinx in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from bioverse==1.1.8) (0.9.7)
# Requirement already satisfied: ipykernel in /Users/bioversedeveloper/Library/Python/3.12/lib/python/site-packages (from bioverse==1.1.8) (6.30.1)
# Requirement already satisfied: astroquery in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from bioverse==1.1.8) (0.4.11)
# Requirement already satisfied: dynesty in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from bioverse==1.1.8) (2.1.5)
# Requirement already satisfied: emcee in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from bioverse==1.1.8) (3.1.6)
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from bioverse==1.1.8) (3.10.6)
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from bioverse==1.1.8) (1.16.2)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from bioverse==1.1.8) (4.67.1)
# Requirement already satisfied: PyQt5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from bioverse==1.1.8) (5.15.11)
# Requirement already satisfied: astropy>=5.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from bioverse==1.1.8) (7.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/bioversedeveloper/Library/Python/3.12/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from astropy>=5.2->bioverse==1.1.8) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2025.4.28.0.37.27 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from astropy>=5.2->bioverse==1.1.8) (0.2025.9.22.0.37.25)
# Requirement already satisfied: PyYAML>=6.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from astropy>=5.2->bioverse==1.1.8) (6.0.3)
# Requirement already satisfied: packaging>=22.0.0 in /Users/bioversedeveloper/Library/Python/3.12/lib/python/site-packages (from astropy>=5.2->bioverse==1.1.8) (25.0)
# Requirement already satisfied: six>=1.5 in /Users/bioversedeveloper/Library/Python/3.12/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: requests>=2.19 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from astroquery->bioverse==1.1.8) (2.32.5)
# Requirement already satisfied: beautifulsoup4>=4.8 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from astroquery->bioverse==1.1.8) (4.13.5)
# Requirement already satisfied: html5lib>=0.999 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from astroquery->bioverse==1.1.8) (1.1)
# Requirement already satisfied: keyring>=15.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from astroquery->bioverse==1.1.8) (25.6.0)
# Requirement already satisfied: pyvo>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from astroquery->bioverse==1.1.8) (1.7)
# Requirement already satisfied: appnope>=0.1.2 in /Users/bioversedeveloper/Library/Python/3.12/lib/python/site-packages (from ipykernel->bioverse==1.1.8) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/bioversedeveloper/Library/Python/3.12/lib/python/site-packages (from ipykernel->bioverse==1.1.8) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/bioversedeveloper/Library/Python/3.12/lib/python/site-packages (from ipykernel->bioverse==1.1.8) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in /Users/bioversedeveloper/Library/Python/3.12/lib/python/site-packages (from ipykernel->bioverse==1.1.8) (9.5.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in /Users/bioversedeveloper/Library/Python/3.12/lib/python/site-packages (from ipykernel->bioverse==1.1.8) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/bioversedeveloper/Library/Python/3.12/lib/python/site-packages (from ipykernel->bioverse==1.1.8) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/bioversedeveloper/Library/Python/3.12/lib/python/site-packages (from ipykernel->bioverse==1.1.8) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in /Users/bioversedeveloper/Library/Python/3.12/lib/python/site-packages (from ipykernel->bioverse==1.1.8) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /Users/bioversedeveloper/Library/Python/3.12/lib/python/site-packages (from ipykernel->bioverse==1.1.8) (7.1.0)
# Requirement already satisfied: pyzmq>=25 in /Users/bioversedeveloper/Library/Python/3.12/lib/python/site-packages (from ipykernel->bioverse==1.1.8) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in /Users/bioversedeveloper/Library/Python/3.12/lib/python/site-packages (from ipykernel->bioverse==1.1.8) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/bioversedeveloper/Library/Python/3.12/lib/python/site-packages (from ipykernel->bioverse==1.1.8) (5.14.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->bioverse==1.1.8) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->bioverse==1.1.8) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->bioverse==1.1.8) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->bioverse==1.1.8) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->bioverse==1.1.8) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->bioverse==1.1.8) (3.2.5)
# Requirement already satisfied: docutils>=0.18.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nbsphinx->bioverse==1.1.8) (0.21.2)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nbsphinx->bioverse==1.1.8) (3.1.6)
# Requirement already satisfied: nbconvert!=5.4,>=5.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nbsphinx->bioverse==1.1.8) (7.16.6)
# Requirement already satisfied: nbformat in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nbsphinx->bioverse==1.1.8) (5.10.4)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sphinx->bioverse==1.1.8) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sphinx->bioverse==1.1.8) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sphinx->bioverse==1.1.8) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sphinx->bioverse==1.1.8) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sphinx->bioverse==1.1.8) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sphinx->bioverse==1.1.8) (2.0.0)
# Requirement already satisfied: Pygments>=2.17 in /Users/bioversedeveloper/Library/Python/3.12/lib/python/site-packages (from sphinx->bioverse==1.1.8) (2.19.2)
# Requirement already satisfied: snowballstemmer>=2.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sphinx->bioverse==1.1.8) (3.0.1)
# Requirement already satisfied: babel>=2.13 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sphinx->bioverse==1.1.8) (2.17.0)
# Requirement already satisfied: alabaster>=0.7.14 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sphinx->bioverse==1.1.8) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sphinx->bioverse==1.1.8) (1.4.1)
# Requirement already satisfied: PyQt5-sip<13,>=12.15 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from PyQt5->bioverse==1.1.8) (12.17.0)
# Requirement already satisfied: PyQt5-Qt5<5.16.0,>=5.15.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from PyQt5->bioverse==1.1.8) (5.15.17)
# Requirement already satisfied: soupsieve>1.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from beautifulsoup4>=4.8->astroquery->bioverse==1.1.8) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from beautifulsoup4>=4.8->astroquery->bioverse==1.1.8) (4.15.0)
# Requirement already satisfied: webencodings in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from html5lib>=0.999->astroquery->bioverse==1.1.8) (0.5.1)
# Requirement already satisfied: decorator in /Users/bioversedeveloper/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel->bioverse==1.1.8) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Users/bioversedeveloper/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel->bioverse==1.1.8) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/bioversedeveloper/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel->bioverse==1.1.8) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /Users/bioversedeveloper/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel->bioverse==1.1.8) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/bioversedeveloper/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel->bioverse==1.1.8) (3.0.52)
# Requirement already satisfied: stack_data in /Users/bioversedeveloper/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel->bioverse==1.1.8) (0.6.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jinja2->nbsphinx->bioverse==1.1.8) (3.0.2)
# Requirement already satisfied: platformdirs>=2.5 in /Users/bioversedeveloper/Library/Python/3.12/lib/python/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->bioverse==1.1.8) (4.4.0)
# Requirement already satisfied: jaraco.classes in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from keyring>=15.0->astroquery->bioverse==1.1.8) (3.4.0)
# Requirement already satisfied: jaraco.functools in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from keyring>=15.0->astroquery->bioverse==1.1.8) (4.3.0)
# Requirement already satisfied: jaraco.context in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from keyring>=15.0->astroquery->bioverse==1.1.8) (6.0.1)
# Requirement already satisfied: bleach[css]!=5.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->bioverse==1.1.8) (6.2.0)
# Requirement already satisfied: defusedxml in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->bioverse==1.1.8) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->bioverse==1.1.8) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->bioverse==1.1.8) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->bioverse==1.1.8) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->bioverse==1.1.8) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nbformat->nbsphinx->bioverse==1.1.8) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nbformat->nbsphinx->bioverse==1.1.8) (4.25.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests>=2.19->astroquery->bioverse==1.1.8) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests>=2.19->astroquery->bioverse==1.1.8) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests>=2.19->astroquery->bioverse==1.1.8) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests>=2.19->astroquery->bioverse==1.1.8) (2024.2.2)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert!=5.4,>=5.3->nbsphinx->bioverse==1.1.8) (1.4.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/bioversedeveloper/Library/Python/3.12/lib/python/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->bioverse==1.1.8) (0.8.5)
# Requirement already satisfied: attrs>=22.2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->nbsphinx->bioverse==1.1.8) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->nbsphinx->bioverse==1.1.8) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->nbsphinx->bioverse==1.1.8) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->nbsphinx->bioverse==1.1.8) (0.27.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/bioversedeveloper/Library/Python/3.12/lib/python/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->bioverse==1.1.8) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/bioversedeveloper/Library/Python/3.12/lib/python/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->bioverse==1.1.8) (0.2.14)
# Requirement already satisfied: more-itertools in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jaraco.classes->keyring>=15.0->astroquery->bioverse==1.1.8) (10.8.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/bioversedeveloper/Library/Python/3.12/lib/python/site-packages (from stack_data->ipython>=7.23.1->ipykernel->bioverse==1.1.8) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/bioversedeveloper/Library/Python/3.12/lib/python/site-packages (from stack_data->ipython>=7.23.1->ipykernel->bioverse==1.1.8) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/bioversedeveloper/Library/Python/3.12/lib/python/site-packages (from stack_data->ipython>=7.23.1->ipykernel->bioverse==1.1.8) (0.2.3)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Tutorial 1: Generating planetary systems (Data Saving Version)
#
# This modified tutorial script runs the simulation steps and saves the resulting planetary sample to a CSV file for use as a test baseline.
#
# ## Setup
#
# Let's start by importing the necessary modules.

# %%
# Import numpy, pandas, and os
import numpy as np
import pandas as pd
import os
import json

# Set a fixed random seed for reproducibility
np.random.seed(42)

# Import the Generator class and constants
from bioverse.generator import Generator
from bioverse.constants import ROOT_DIR

# %% [markdown]
# ## Loading and Configuring the Generator
#
# We load the `transit` generator and modify key arguments.

# %%
# Open the transit mode generator
generator = Generator('transit')

# Set eta_Earth = 15%
generator.set_arg('eta_Earth', 0.15)

# Set transit_mode = True
generator.set_arg('transit_mode', True)

val = str(generator.get_arg('transit_mode'))
print("\nThe current value of transit_mode is {:s}".format(val))
# Out:
# The current value of transit_mode is True

# %% [markdown]
# ## Defining and Inserting a Custom Step
#
# We define the `oceans` function and insert it into the generator.

# %%
# Define a function that accepts and returns a Table object
def oceans(d, f_ocean_min=0, f_ocean_max=1):
    # First, assign zero for all planets
    d['f_ocean'] = np.zeros(len(d))

    # Next, assign a random non-zero value for exo-Earth candidates
    EEC = d['EEC']
    d['f_ocean'][EEC] = np.random.uniform(f_ocean_min, f_ocean_max, size=EEC.sum())

    # Finally, return the Table with its new column
    return d

# Insert this function at the end of the Generator
generator.insert_step(oceans)

# %% [markdown]
# ## Running the Generator and Saving Data
#
# We run the generator and save the final sample data to a CSV file.

# %%
# Run the generator with all custom settings
sample = generator.generate(d_max=100, f_ocean_min=0.3, f_ocean_max=0.7)

print("Generated a sample of {:d} transiting planets including {:d} exo-Earth candidates.".format(len(sample), sample['EEC'].sum()))

# Convert the sample (Table) dictionary to a pandas DataFrame
df = pd.DataFrame(sample)

# Save the DataFrame to a CSV file for baseline testing
output_filename = 'tutorial_sample_data.csv'
df.to_csv(output_filename, index=False)

print(f"Final simulated sample data saved to {output_filename}")
# Out:
# Generated a sample of 16871 transiting planets including 1133 exo-Earth candidates.
# Final simulated sample data saved to tutorial_sample_data.csv

# %% [markdown]
# ## Clean Up
#
# The remaining tutorial steps involve saving the Generator to disk and performing cleanup. We will execute the cleanup steps to ensure the test environment remains clean.

# %%
# First, save and reload the generator to simulate the full tutorial flow
generator.save('transit_oceans')
generator = Generator('transit_oceans')

# The file creation steps are skipped in this testing file, 
# but we include the file cleanup to ensure a clean state.

# Write a dummy function file to ensure cleanup runs, as per the original tutorial logic
func = """# dummy function
def oceans(d, f_ocean_min=0, f_ocean_max=1): return d"""
with open(ROOT_DIR+'/example_oceans.py', 'w') as f:
    f.write(func)

# Clean up files created during the exercise
trash = [ROOT_DIR+'/Objects/Generators/transit_oceans.pkl', ROOT_DIR+'/example_oceans.py']
for filename in trash:
    if os.path.exists(filename):
        os.remove(filename)
        print(f"Cleaned up: {filename}")
# Out:
# Cleaned up: /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/bioverse/Objects/Generators/transit_oceans.pkl
# Cleaned up: /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/bioverse/example_oceans.py
